# %% [markdown]
# # Pré-processamento dos dados

# %%
! pip install geopandas
! pip install fiona==1.9.6
! pip install dash dash-leaflet geopandas pandas

# ! pip install --upgrade geopandas
# ! pip show geopandas
# ! pip show fiona
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/lib64/python3.13/site-packages (from geopandas) (2.2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in /usr/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fiona==1.9.6
#   Using cached fiona-1.9.6.tar.gz (411 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [3 lines of output]
#       <string>:86: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#       WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#       CRITICAL:root:A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (3.0.4)
# Requirement already satisfied: dash-leaflet in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (1.1.3)
# Requirement already satisfied: geopandas in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (1.0.1)
# Requirement already satisfied: pandas in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (6.1.1)
# Requirement already satisfied: importlib-metadata in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/lib/python3.13/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /usr/lib/python3.13/site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.13/site-packages (from dash) (74.1.3)
# Requirement already satisfied: dash-extensions>=2.0.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-leaflet) (2.0.4)
# Requirement already satisfied: dash_svg in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-leaflet) (0.0.12)
# Requirement already satisfied: protobuf>=6.30.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-leaflet) (6.31.0)
# Requirement already satisfied: geobuf>=2.0.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-leaflet) (2.0.0)
# Requirement already satisfied: pyyaml in /usr/lib64/python3.13/site-packages (from dash-leaflet) (6.0.2)
# Requirement already satisfied: colorcet in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-leaflet) (3.1.0)
# Requirement already satisfied: numpy>=1.22 in /usr/lib64/python3.13/site-packages (from geopandas) (2.2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in /usr/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.13/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: more-itertools>=10.6.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-extensions>=2.0.0->dash-leaflet) (10.7.0)
# Requirement already satisfied: jsbeautifier>=1.15.4 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-extensions>=2.0.0->dash-leaflet) (1.15.4)
# Requirement already satisfied: Flask-Caching>=2.3.1 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.3.1)
# Requirement already satisfied: dataclass-wizard>=0.35.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-extensions>=2.0.0->dash-leaflet) (0.35.0)
# Requirement already satisfied: pydantic>=2.10.6 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.11.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/lib/python3.13/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: six in /usr/lib/python3.13/site-packages (from geobuf>=2.0.0->dash-leaflet) (1.17.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from plotly>=5.0.0->dash) (1.40.0)
# Requirement already satisfied: certifi in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/lib64/python3.13/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.13/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.13/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.13/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: cachelib>=0.9.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from Flask-Caching>=2.3.1->dash-extensions>=2.0.0->dash-leaflet) (0.13.0)
# Requirement already satisfied: editorconfig>=0.12.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from jsbeautifier>=1.15.4->dash-extensions>=2.0.0->dash-leaflet) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/luisalopescarvalhaes/.local/lib/python3.13/site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.4.1)

# %%
# imports
import re
import math
import pandas as pd
import numpy as np
from pyproj import Transformer

# %%
# reprojetando os bairros

import geopandas as gpd

# Ler o arquivo original em EPSG:31983
gdf = gpd.read_file("BAIRRO_OFICIAL_bh.geojson")

# Reprojetar para EPSG:4326 (graus decimais)
gdf = gdf.to_crs("EPSG:4326")

# Salvar novo arquivo GeoJSON
gdf.to_file("BAIRRO_OFICIAL_bh_reprojetado.geojson", driver="GeoJSON")

# %% [markdown]
# ## Fazendo o dataframe dos bares

# %%
# definindo as colunas - coluna coords_geo
df =  pd.read_csv("dados_com_coordenadas.csv") # Gerado pelo script_coordenadas

# define o transformador de UTM Zone 23S (EPSG:31983) para WGS 84 (EPSG:4326)
transformer = Transformer.from_crs("EPSG:31983", "EPSG:4326", always_xy=True)

def converter_utm_para_latlon(geom_str):
    match = re.search(r"POINT \((-?[\d\.]+) (-?[\d\.]+)\)", geom_str)
    if match:
        x = float(match.group(1))
        y = float(match.group(2))
        lon, lat = transformer.transform(x, y)
        return (lat, lon)
    return None  

df["COORD_GEO"] = df["GEOMETRIA"].apply(converter_utm_para_latlon)

# print(df.dtypes)
# df.head()

# %%
for col in [
    "ID_ATIV_ECON_ESTABELECIMENTO",
    "CNAE_PRINCIPAL",
    "DATA_INICIO_ATIVIDADE",
    "GEOMETRIA"
]:
    df[col] = df[col].replace("indisponivel", "NA")

df["NOME_FANTASIA"] = df.apply(
    lambda row: row["NOME"] if row["NOME_FANTASIA"] == "indisponivel" else row["NOME_FANTASIA"],
    axis=1
)

df["ID_ATIV_ECON_ESTABELECIMENTO"] = df["ID_ATIV_ECON_ESTABELECIMENTO"].astype(str)
df["ID_CDB"] = df["CDB"].astype(int).apply(lambda x: f"{x:03}")
df.drop(columns=["CDB"], inplace=True)
df["CNAE_PRINCIPAL"] = df["CNAE_PRINCIPAL"].astype(str)

df["DATA_INICIO_ATIVIDADE"] = df["DATA_INICIO_ATIVIDADE"].apply(
    lambda x: pd.to_datetime(x, format="%d-%m-%Y").date() if x != "NA" else "NA"
)


for col in [
    "IND_POSSUI_ALVARA",
    "ENDERECO_COMPLETO",
    "NOME",
    "NOME_FANTASIA",
    "GEOMETRIA"
]:
    df[col] = df[col].astype(str)

def parse_coord_str(x):
    if isinstance(x, str):
        coords = tuple(map(float, x.strip().replace("(", "").replace(")", "").split(",")))
    elif isinstance(x, (tuple, list)):
        coords = x
    elif isinstance(x, float) or isinstance(x, int):
        coords = (float(x), float(x))
    else:
        coords = (float('nan'), float('nan'))
    
    return tuple(round(c, 7) for c in coords)

df["COORDS"] = df["COORDS"].apply(parse_coord_str)
df["COORD_GEO"] = df["COORD_GEO"].apply(parse_coord_str)



cols = df.columns.tolist()
cols.insert(1, cols.pop(cols.index("ID_CDB")))
df = df[cols]

# print(df.dtypes)
# df.head()
# Out:
# ID_ATIV_ECON_ESTABELECIMENTO    object
# ID_CDB                          object
# CNAE_PRINCIPAL                  object
# DATA_INICIO_ATIVIDADE           object
# IND_POSSUI_ALVARA               object
# ENDERECO_COMPLETO               object
# NOME                            object
# NOME_FANTASIA                   object
# GEOMETRIA                       object
# COORDS                          object
# COORD_GEO                       object
# dtype: object

# %%
df.to_csv("complete_bar_data.csv", index=False, encoding="utf-8")

# %% [markdown]
# ### Buscando os dados do Comida di Buteco cuja a API não encontrou as coordenadas

# %%
def encontrar_bares_sem_coords(df):
    def parse_coord(x):
        if isinstance(x, tuple):
            return x
        if isinstance(x, str):
            x = x.strip().replace("(", "").replace(")", "")
            parts = x.split(",")
            if len(parts) != 2:
                return (np.nan, np.nan)
            try:
                return (float(parts[0]), float(parts[1]))
            except:
                return (np.nan, np.nan)
        return (np.nan, np.nan)

    def is_nan_tuple(t):
        return (
            isinstance(t, tuple) and len(t) == 2 and
            math.isnan(t[0]) and math.isnan(t[1])
        )

    df["ID_CDB"] = df["ID_CDB"].astype(str)

    df["COORDS_parsed"] = df["COORDS"].apply(parse_coord)
    df["COORD_GEO_parsed"] = df["COORD_GEO"].apply(parse_coord)

    # Filtros
    filtro_cdb = df["ID_CDB"] != "000"
    filtro_coords_nan = df["COORDS_parsed"].apply(is_nan_tuple)
    filtro_coordgeo_nan = df["COORD_GEO_parsed"].apply(is_nan_tuple)

    resultado = df.loc[
        filtro_cdb & filtro_coords_nan & filtro_coordgeo_nan,
        ["NOME", "ENDERECO_COMPLETO"]
    ].reset_index(drop=True)

    df.drop(columns=["COORDS_parsed", "COORD_GEO_parsed"], inplace=True)

    return resultado

# %%
df = pd.read_csv("complete_bar_data.csv")
resultado = encontrar_bares_sem_coords(df)
print(resultado)
# Out:
#                      NOME                                  ENDERECO_COMPLETO
# 0              MAMUTE BAR  RUA BRAS CUBAS, 116, CRUZEIRO, BELO HORIZONTE,...
# 1          CONECTADOS BAR  AVENIDA FRANCISCO SA, 280, PRADO, BELO HORIZON...
# 2               S.O.S PUB  AVENIDA PADRE JOSE MAURICIO, 1126, VISTA ALEGR...
# 3      KÖBES EMPORIUM BAR  RUA PROFESSOR RAIMUNDO NONATO, 31, SANTA TEREZ...
# 4            BUTECO'S BAR  RUA ERNESTO BRAGA, 2, JARDIM ATLANTICO, BELO H...
# 5       DECK BOI NA BRASA  RUA DESEMBARGADOR JOSÉ SATYRO, 302, MANACAS, B...
# 6            BAR DO ROMEU  RUA ANIRY, 8, GUARANI, BELO HORIZONTE, MG, BRASIL
# 7       COMPANHIA DO DINO  RUA JOAQUIM CLEMENTE, 682, FLORAMAR, BELO HORI...
# 8          ANDRADE'S BEER  RUA DONA GENI, 32, VENDA NOVA, BELO HORIZONTE,...
# 9      TROPEIRO DO LISBOA  AVENIDA LEONTINO FRANCISCO ALVES, 506, SERRA V...
# 10   ESPETINHOS DO PAULÃO  RUA ALVARO MATA, 466, NOVA CACHOEIRINHA, BELO ...
# 11                  MULÃO  RUA MARAMBAIA, 291, CAICARAS, BELO HORIZONTE, ...
# 12        SANTUÁRIO RETRÔ  RUA CAPELA NOVA, 150, MINAS BRASIL, BELO HORIZ...
# 13            THE BUTCHER  AVENIDA RESSACA, 353, CORACAO EUCARISTICO, BEL...

# %% [markdown]
# ### Ajusta manual
# Pesquisei no Google Maps e adicionei manualmente ao `complete_bar_data.csv`, assim garantimos que pelo menos COORDS ou COORD_GEO tem alguma coordenada, logo sempre conseguimos printar marcadores para os bares.
#
# BUTECO'S BAR: Rua Ernesto Braga 02 Jardim Atlântico, Belo Horizonte -> -19.8478398,-43.9870588
# DECK BOI NA BRASA: Rua Desembargador José Satyro, 302 - Castelo, Belo Horizonte -> -19.8876361!4d-43.9964471
# COMPANHIA DO DINO: Avenida Joaquim Clemente, 682 - Floramar, Belo Horizonte -> -19.8372406!4d-43.9332652

# %%
# vamos usar os bares indexados pelo ID

df = pd.read_csv("complete_bar_data.csv")

df["ID_ATIV_ECON_ESTABELECIMENTO"] = df["ID_ATIV_ECON_ESTABELECIMENTO"].fillna(df["ID_CDB"])
df["ID_ATIV_ECON_ESTABELECIMENTO"] = df["ID_ATIV_ECON_ESTABELECIMENTO"].astype(float).astype(int).astype(str)
df = df.set_index("ID_ATIV_ECON_ESTABELECIMENTO")

# Salva mantendo o índice (que é importante aqui!)
df.to_csv("complete_bar_data1.csv", index=True)
